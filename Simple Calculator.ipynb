# %% [markdown]
# Simple calculator which performs arithmetic operations

# %%
def add(num1,num2):
    return num1+num2

# %%
def sub(num1,num2):
    return num1-num2

# %%
def multiply(num1,num2):
    return num1*num2

# %%
def divide(num1,num2):
    return num1/num2

# %%
print("select operation\n"
"1. Addition\n"
"2. Subtraction\n"
"3. Multiplication\n"
"4. Division")
operation_input=int(input("Enter your choice from above operations: "))
num1=int(input("Enter First Number: "))
num2=int(input("Enter Second Number: "))

if operation_input==1:
    print(f"{num1} + {num2} = {add(num1,num2)}")

elif operation_input==2:
    print(f"{num1} - {num2} = {sub(num1,num2)}")

elif operation_input==3:
    print(f"{num1} * {num2} = {multiply(num1,num2)}")

elif operation_input==4:
    print(f"{num1} / {num2} = {divide(num1,num2)}")

else:
    print("Invalid Input ")
# Out:
# select operation
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice from above operations: 5
# Enter First Number: 6
# Enter Second Number: 2
# Invalid Input
